# %%
x = var('x')

# %%
y = 3.8*x^5 - 18.6*x^3

# %%
d = derivative(y, x)

# %%
d
# Out:
# 19.0000000000000*x^4 - 55.8000000000000*x^2

# %%
plot(y,(x,-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(d,(x,-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq = 19*x^4 - 55.8*x^2 == 0

# %%
eq.find_root(0.1, 3)
# Out:
# 1.7137217117324381

# %%
eq.find_root(-3, -.1)
# Out:
# -1.7137217117324381

# %%
eq.find_root(-.1, .1)
# Out:
# 0.0

# %%
f = (x*sqrt(1+3*x))/(1 + x^3)

# %%
d2 = derivative(f, x)

# %%
d2
# Out:
# -3*sqrt(3*x + 1)*x^3/(x^3 + 1)^2 + sqrt(3*x + 1)/(x^3 + 1) + 3/2*x/((x^3 + 1)*sqrt(3*x + 1))
